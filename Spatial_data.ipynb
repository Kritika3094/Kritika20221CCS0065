# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium
mymap=folium.Map(location=[1.366623,103.821285],
                 width=950,
                 height=550,
                 zoom_start=12,
                 titles='openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70de168dd3f3efc08dc474ade24c3084 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70de168dd3f3efc08dc474ade24c3084&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70de168dd3f3efc08dc474ade24c3084 = L.map(
#                 &quot;map_70de168dd3f3efc08dc474ade24c3084&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;openstreetmap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce2e1ef9281f1addee7babded024080d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70de168dd3f3efc08dc474ade24c3084);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
mymap=folium.Map(location=[12.971599, 77.594566])
folium.Marker(location=[12.971599, 77.594566],popup='Default popup Marker1',tooltip='Banglore').add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddecd4d99a64c6c3829f9a07d377faf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddecd4d99a64c6c3829f9a07d377faf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddecd4d99a64c6c3829f9a07d377faf8 = L.map(
#                 &quot;map_ddecd4d99a64c6c3829f9a07d377faf8&quot;,
#                 {
#                     center: [12.971599, 77.594566],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_373dde178a49d63882dd395167838491 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ddecd4d99a64c6c3829f9a07d377faf8);
#
#
#             var marker_b9aae1d60bdbf302687b508be51bdfb4 = L.marker(
#                 [12.971599, 77.594566],
#                 {}
#             ).addTo(map_ddecd4d99a64c6c3829f9a07d377faf8);
#
#
#         var popup_ab6b3db43912e52fba9da58d432cd68d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_021a40a07e0500a3a35f74ff1b488436 = $(`&lt;div id=&quot;html_021a40a07e0500a3a35f74ff1b488436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Default popup Marker1&lt;/div&gt;`)[0];
#                 popup_ab6b3db43912e52fba9da58d432cd68d.setContent(html_021a40a07e0500a3a35f74ff1b488436);
#
#
#
#         marker_b9aae1d60bdbf302687b508be51bdfb4.bindPopup(popup_ab6b3db43912e52fba9da58d432cd68d)
#         ;
#
#
#
#
#             marker_b9aae1d60bdbf302687b508be51bdfb4.bindTooltip(
#                 `&lt;div&gt;
#                      Banglore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
#BANGLORE MAP WITH FAMOUS PLACES INCLUDING IMAGES
# Latitude and longitude coordinates of Bangalore
bangalore_coords = (12.9716, 77.5946)

# Create a map centered around Bangalore
map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)

# Define famous places and their coordinates in Bangalore

places = {
    "Mantri Square":(12.991808891296387,77.57083892822266),
    "Church Street":(12.9755764,77.6025727),
    "Cubbon Park": (12.9757, 77.5929),
    "Bangalore Palace": (12.97194, 77.5936),
    "Vidhana Soudha": (12.979693, 77.590658),
    "Presidency University": (13.1682, 77.5354),
    "Wonderla": (12.834300, 77.414558)   ,
    "M Chinnaswamy Stadium": (12.9784, 77.5994),
    "Isckon temple": (13.00981, 77.55109),
    "Jain university":(12.97194,77.59369),
    "RV College":(12.924066,77.4982484),
}



# Define images for each place
images = {
    "Mantri Square":"https://lh3.googleusercontent.com/p/AF1QipM8b7fD0N4eBg3SIDBNOLDYQ4klo2xwPpFAcO9U=s680-w680-h510",
    "Church Street": "https://i.ytimg.com/vi/ft3ihb6ie5M/sddefault.jpg",
    "Cubbon Park": "https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&pid=Api&P=0&h=180",
    "Bangalore Palace": "https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&pid=Api&P=0&h=180",
    "Vidhana Soudha": "https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&pid=Api&P=0&h=180",
    "Presidency University": "https://tse1.mm.bing.net/th?id=OIP.X_YkcFxJv_Hy_fDFMfJv-gHaE8&pid=Api&P=0&h=180",
    "Wonderla": "https://tse2.mm.bing.net/th?id=OIP.p-jWkEz-iJvmLc4PtPFwAAHaE8&pid=Api&P=0&h=180",
    "M Chinnaswamy Stadium": "https://tse1.mm.bing.net/th?id=OIP.NepFTWdG0NbPcLL2XFI-jQHaEK&pid=Api&P=0&h=180",
    "Isckon temple": "https://tse1.mm.bing.net/th?id=OIP.76ttZ61WrTg-a-nuYSpdPAHaFj&pid=Api&P=0&h=180",
    "Jain university":"https://images.shiksha.com/mediadata/images/articles/1588857705phpchLo4J.jpeg",
     "RV College":"https://edufever.in/colleges/wp-content/uploads/2022/05/RV-College-of-Engineering-Bangalore.jpg"
}

# Add markers for each place
for place, coords in places.items():
    popup_content = f'<b>{place}</b><br><img src="{images[place]}" width="200">'
    folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)

# Display the map
map_bangalore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e20399f729c285a1b89e05163c40190 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e20399f729c285a1b89e05163c40190&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e20399f729c285a1b89e05163c40190 = L.map(
#                 &quot;map_8e20399f729c285a1b89e05163c40190&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_969ed1a697ff88ef02a5186d2d7f285a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e20399f729c285a1b89e05163c40190);
#
#
#             var marker_ca07f04e107afd24f4895f1cc529b51a = L.marker(
#                 [12.991808891296387, 77.57083892822266],
#                 {}
#             ).addTo(map_8e20399f729c285a1b89e05163c40190);
#
#
#         var popup_fa2d0a1f047bd49b62f03d53257100bb = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f46f8a5b5e31a79e3130fbc9efd3f9c4 = $(`&lt;div id=&quot;html_f46f8a5b5e31a79e3130fbc9efd3f9c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mantri Square&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://lh3.googleusercontent.com/p/AF1QipM8b7fD0N4eBg3SIDBNOLDYQ4klo2xwPpFAcO9U=s680-w680-h510&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_fa2d0a1f047bd49b62f03d53257100bb.setContent(html_f46f8a5b5e31a79e3130fbc9efd3f9c4);
#
#
#
#         marker_ca07f04e107afd24f4895f1cc529b51a.bindPopup(popup_fa2d0a1f047bd49b62f03d53257100bb)
#         ;
#
#
#
#
#             var marker_e1fcfc55c5b5b06127801fb130ba6b08 = L.marker(
#                 [12.9755764, 77.6025727],
#                 {}
#             ).addTo(map_8e20399f729c285a1b89e05163c40190);
#
#
#         var popup_7cb1f46aa92b120fec33094035339633 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_09f470203fd83a660043256189700d73 = $(`&lt;div id=&quot;html_09f470203fd83a660043256189700d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Church Street&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://i.ytimg.com/vi/ft3ihb6ie5M/sddefault.jpg&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_7cb1f46aa92b120fec33094035339633.setContent(html_09f470203fd83a660043256189700d73);
#
#
#
#         marker_e1fcfc55c5b5b06127801fb130ba6b08.bindPopup(popup_7cb1f46aa92b120fec33094035339633)
#         ;
#
#
#
#
#             var marker_5505fe2e27818ad37a9a5c08dffd62c0 = L.marker(
#                 [12.9757, 77.5929],
#                 {}
#             ).addTo(map_8e20399f729c285a1b89e05163c40190);
#
#
#         var popup_8b622a927e3653428878b3acf8141d8d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_780b84447590ba32002e64b739742fd9 = $(`&lt;div id=&quot;html_780b84447590ba32002e64b739742fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cubbon Park&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_8b622a927e3653428878b3acf8141d8d.setContent(html_780b84447590ba32002e64b739742fd9);
#
#
#
#         marker_5505fe2e27818ad37a9a5c08dffd62c0.bindPopup(popup_8b622a927e3653428878b3acf8141d8d)
#         ;
#
#
#
#
#             var marker_1f78ddecb321d546d2a9031cf128173b = L.marker(
#                 [12.97194, 77.5936],
#                 {}
#             ).addTo(map_8e20399f729c285a1b89e05163c40190);
#
#
#         var popup_616c14b9b2cfd2510cd56ce6b1d53d32 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_0f1c7d23b39a58a308f9b2e31f7e09c4 = $(`&lt;div id=&quot;html_0f1c7d23b39a58a308f9b2e31f7e09c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore Palace&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_616c14b9b2cfd2510cd56ce6b1d53d32.setContent(html_0f1c7d23b39a58a308f9b2e31f7e09c4);
#
#
#
#         marker_1f78ddecb321d546d2a9031cf128173b.bindPopup(popup_616c14b9b2cfd2510cd56ce6b1d53d32)
#         ;
#
#
#
#
#             var marker_824a37ca9f2f5ce47e5075e8bc7c1093 = L.marker(
#                 [12.979693, 77.590658],
#                 {}
#             ).addTo(map_8e20399f729c285a1b89e05163c40190);
#
#
#         var popup_0e369e0a8e2414fd3c19c531ee618276 = L.popup({&quot;maxWidth&quot;: 300});
